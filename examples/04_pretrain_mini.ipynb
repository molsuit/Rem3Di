# %% [markdown]
# # Pretrain from scratch (smoke run)
#
# A tiny denoising-pretraining run to check the pipeline wires up end to end. Uses the `--max_*` smoke caps, so it trains on a handful of molecules for one epoch.
#
# **Needs:** a GPU + MACE deps, a small MoleculeDataset, and a training dir with `training_config.yaml` + `architecture_config.yaml` (copy `configs/training/pcqm_ablation_novicreg/pcqm_baseline/` and edit paths). See [docs/train-from-scratch.md](../docs/train-from-scratch.md).

# %%
# Smoke run: 100 train / 20 val molecules, 1 epoch. Edit the config path.
# !python ../scripts/run_online_embedding_denoising_pretraining.py \
    --training_config my_run/training_config.yaml \
    --max_train 100 --max_val 20 --max_epochs 1

# %% [markdown]
# A completed run writes `encoder.pth`, `atomic_preprocessor.pth`, `geometric_preprocessor.pth`, and `post_training_architecture_config.yaml` into a timestamped dir under `output_base` — exactly what [`01_get_descriptors.ipynb`](01_get_descriptors.ipynb) loads.
#
# Drop the `--max_*` flags for a full run.
